# %% [markdown]
# # Gerekli Kutuphanelerin Import Edilmesi

# %%
import os
import sys
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from sklearn import preprocessing
from sklearn.preprocessing import scale
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Data Setinden Cekilecek Veriler Icin Gerekli Variable Tanımlamaları

# %%
# Kaç adet train edeceğimiz veri olduğunu len_trainData değişkenine
# Kaç adet test edeceğimiz veri olduğunu len_testData değişkenine atıyoruz
# Ben 194 data'ya sahip olduğum ve test oranının 20% olmasını istediğim için aşağıdaki şekilde atadım
len_trainData = int( 194 * 0.8)
len_testData = int( 194 * 0.2)
# Görsellerin Boyutu
image_sizeX = 128
image_sizeY = 128

# Train edilecek görselleri daha sonra içine atamak için oluşturduğum boş listeler
train_data = []
train_mask1 = []
train_mask2 = []

# Test edilecek görselleri daha sonra içine atamak için oluşturduğum boş listeler
test_data = []
test_mask1 = []
test_mask2 = []

# %% [markdown]
# # Dataseti Boş Listelere Yükleme

# %%
for i in range(len_trainData - 1):
    # matplotlib.image kütüphanesinin içinde gelen imread ile dosyaları okuyup geçici bir değişkende saklıyoruz
    x = mpimg.imread('./dataset/data/%d.png'%(i+1))
    
    # Bu görsel bize normal bir liste olarak geldiği için reshape ederek 128x128 hale getiriyoruz. Normalde 16384 (128*128) değişken içeren bir listeydi
    x = x.reshape(image_sizeX,image_sizeY,1)
    
    # bu görseli listeye atıyoruz.
    train_data.append(x)
    
    # Aynı işlemi masklar için de yapıyoruz
    
    m1 = mpimg.imread('./dataset/mask1/%d.png'%(i+1))
    m1 = m1.reshape(image_sizeX,image_sizeY,1)
    train_mask1.append(m1)
    m2 = mpimg.imread('./dataset/mask2/%d.png'%(i+1))
    m2 = m2.reshape(image_sizeX,image_sizeY,1)
    train_mask2.append(m2)

# Test verileri için yeni bir foreach loop'u
# Tüm verilerin sayısı len_trainData + len_testData toplamına eşit ve en son (len_trainData-1). değeri zaten train data'da atadık
for i in range(len_trainData, len_trainData + len_testData):
    x = mpimg.imread('./dataset/data/%d.png'%(i+1))
    x = x.reshape(image_sizeX,image_sizeY,1)
    test_data.append(x)
    
    m1 = mpimg.imread('./dataset/mask1/%d.png'%(i+1))
    m1 = m1.reshape(image_sizeX,image_sizeY,1)
    test_mask1.append(m1)
    
    m2 = mpimg.imread('./dataset/mask2/%d.png'%(i+1))
    m2 = m2.reshape(image_sizeX,image_sizeY,1)
    test_mask2.append(m2)

# %% [markdown]
# # Verileri Numpy Arraylere Çevirme

# %%
# Şimdi ise gelen veriler çok büyük matrislerden oluştuğu için bunlarla daha rahat çalışma amacıyla numpy 
train_data = np.array(train_data)
train_mask1 = np.array(train_mask1)
train_mask2 = np.array(train_mask2)
test_data = np.array(test_data)
test_mask1 = np.array(test_mask1)
test_mask2 = np.array(test_mask2)

# %% [markdown]
# # Unet Modeli Katmanlarının Tanımlanması

# %%
# multi_scale fonksiyonu, çeşitli filtre boyutlarında konvolüsyon katmanlarını birleştirerek çok ölçekli bir yapı oluşturur.
# Bu yapı, ağın farklı ölçeklerdeki özellikleri öğrenmesine olanak tanır.
def multi_scale(x, filters, padding="same", strides=1):
    
    # Giriş verisi üzerine 1x1 boyutlu konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c1 = keras.layers.Conv2D(filters, (1,1), padding=padding, strides=strides, activation="relu")(x)
    
    # Giriş verisi üzerine 3x3 boyutlu konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c3 = keras.layers.Conv2D(filters, (3,3), padding=padding, strides=strides, activation="relu")(x)
    
    # Giriş verisi üzerine 5x5 boyutlu konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c5 = keras.layers.Conv2D(filters, (5,5), padding=padding, strides=strides, activation="relu")(x)
    
    # Giriş verisi üzerine 7x7 boyutlu konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c7 = keras.layers.Conv2D(filters, (7,7), padding=padding, strides=strides, activation="relu")(x)
    
    # Oluşturulan tüm konvolüsyon katmanları birleştirilerek çok ölçekli bir yapı elde edilir.
    c = keras.layers.Concatenate()([c1, c3, c5, c7])
    return c

# down_block2 fonksiyonu, Unet mimarisindeki indirgeme (downsampling) bloğunu tanımlar.
# Bu blok, konvolüsyon katmanları ve max pooling katmanları içerir.
def down_block2(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    
    # Filtre sayısının dörtte biri kadar bir değer hesaplanır.
    f = int(filters/4)
    
    # multi_scale fonksiyonu kullanılarak çok ölçekli bir yapı elde edilir.
    c = multi_scale(x, f)
    
    # Oluşturulan yapı üzerine konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    
    # Max pooling işlemi uygulanarak indirgeme yapılan bir katman oluşturulur.
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

# up_block2 fonksiyonu, Unet mimarisindeki genişletme (upsampling) bloğunu tanımlar.
# Bu blok, birleştirme (concatenation) ve konvolüsyon katmanları içerir.
def up_block2(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    # Filtre sayısının dörtte biri kadar bir değer hesaplanır.
    f = int(filters/4)
    
    # Upsampling işlemi uygulanarak boyutları genişletilmiş bir veri oluşturulur.
    us = keras.layers.UpSampling2D((2, 2))(x)
    
    # Oluşturulan veri üzerine konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    us = keras.layers.Conv2D(filters, (2, 2), padding='same', strides=1, activation="relu")(us)
    
    # Önceki katman ile atlanan bağlantılar birleştirilerek yeni bir yapı oluşturulur.
    c = keras.layers.Concatenate()([us, skip])
    
    # Oluşturulan yapı üzerine multi_scale fonksiyonu kullanılarak çok ölçekli bir yapı elde edilir.
    c = multi_scale(c, f)
    
    # Oluşturulan yapı üzerine konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# bottleneck2 fonksiyonu, Unet mimarisindeki darboğaz (bottleneck) bloğunu tanımlar.
# Bu blok, çok ölçekli konvolüsyon katmanları ve standart bir konvolüsyon katmanı içerir.
def bottleneck2(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    # Filtre sayısının dörtte biri kadar bir değer hesaplanır.
    f = int(filters/4)
    
    # multi_scale fonksiyonu kullanılarak çok ölçekli bir yapı elde edilir.
    c = multi_scale(x, f)
    
    # Oluşturulan yapı üzerine konvolüsyon uygulanarak bir konvolüsyon katmanı oluşturulur.
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# # DMRFUnet - 2 Aşamalı Modelin Tanımlanması

# %%
# Bu fonksiyon, Unet mimarisine dayalı olarak özel bir iki aşamalı modeli tanımlar.
# İlk aşamada bir maske tahmin edilir, ikinci aşamada ise bu maske giriş görüntüsü ile birleştirilerek ikinci bir maske tahmin edilir.
def DMRF_UNet():

    f0 = 64
    f = [f0, f0*2, f0*4, f0*8, f0*16]
    inputs = keras.layers.Input((image_sizeX, image_sizeY, 1))
    
    #### model_1
    p0 = inputs
    c1, p1 = down_block2(p0, f[0])
    c2, p2 = down_block2(p1, f[1])
    c3, p3 = down_block2(p2, f[2])
    c4, p4 = down_block2(p3, f[3])
    
    bn = bottleneck2(p4, f[4])
    
    u1 = up_block2(bn, c4, f[3])
    u2 = up_block2(u1, c3, f[2])
    u3 = up_block2(u2, c2, f[1])
    u4 = up_block2(u3, c1, f[0])
    
    output_1 = keras.layers.Conv2D(1, (1, 1), padding="same", activation="relu")(u4)
    model_1 = tf.keras.Model(inputs, output_1)

    #### model_2
    pp0 = keras.layers.Concatenate()([output_1, inputs])
    cc1, pp1 = down_block2(pp0, f[0])
    cc2, pp2 = down_block2(pp1, f[1])
    cc3, pp3 = down_block2(pp2, f[2])
    cc4, pp4 = down_block2(pp3, f[3])
    
    bnn = bottleneck2(pp4, f[4])
    
    uu1 = up_block2(bnn, cc4, f[3])
    uu2 = up_block2(uu1, cc3, f[2])
    uu3 = up_block2(uu2, cc2, f[1])
    uu4 = up_block2(uu3, cc1, f[0])

    output_2 = keras.layers.Conv2D(1, (1, 1), padding="same", activation="elu")(uu4)
    model_2 = tf.keras.Model(inputs, [output_1, output_2])

    return model_2

# get_lr_metric fonksiyonu, bir optimizer nesnesi alarak öğrenme oranını döndüren bir fonksiyon oluşturur.
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr
    return lr

# DMRF_UNet fonksiyonunu kullanarak bir model oluşturuyoruz
model = DMRF_UNet()

# Bu modelin özetini görüntülüyoruz.
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │         32 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │        416 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │        800 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ conv2d[0][0],     │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │     36,928 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      2,080 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     18,464 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     51,232 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │    100,384 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_5[0][0],   │
# │ (Concatenate)       │ 128)              │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │    147,584 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │      8,256 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     73,792 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │    204,864 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    401,472 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_10[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │    590,080 │ concatenate_2[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_14[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │     32,896 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │    295,040 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │    819,328 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 16, 16,    │  1,605,760 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ conv2d_15[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_16[0][0],  │
# │                     │                   │            │ conv2d_17[0][0],  │
# │                     │                   │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ concatenate_3[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ conv2d_19[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 8, 8, 256) │    131,328 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 8, 8, 256) │  1,179,904 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 8, 8, 256) │  3,277,056 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 256) │  6,422,784 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 8, 8,      │          0 │ conv2d_20[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ conv2d_21[0][0],  │
# │                     │                   │            │ conv2d_22[0][0],  │
# │                     │                   │            │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8,      │  9,438,208 │ concatenate_4[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ conv2d_24[0][0]   │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │  2,097,664 │ up_sampling2d[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 16, 16,    │          0 │ conv2d_25[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 16, 16,    │    131,200 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 16, 16,    │  1,179,776 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 16, 16,    │  3,276,928 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │  6,422,656 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 16, 16,    │          0 │ conv2d_26[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_27[0][0],  │
# │                     │                   │            │ conv2d_28[0][0],  │
# │                     │                   │            │ conv2d_29[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ concatenate_6[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ conv2d_30[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 32,    │    524,544 │ up_sampling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 32, 32,    │          0 │ conv2d_31[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │     32,832 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 32, 32,    │    294,976 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │    819,264 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 32, 32,    │  1,605,696 │ concatenate_7[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 32, 32,    │          0 │ conv2d_32[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_33[0][0],  │
# │                     │                   │            │ conv2d_34[0][0],  │
# │                     │                   │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │    590,080 │ concatenate_8[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ conv2d_36[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 64, 64,    │    131,200 │ up_sampling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 64,    │          0 │ conv2d_37[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 64, 64,    │      8,224 │ concatenate_9[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 64,    │     73,760 │ concatenate_9[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 64, 64,    │    204,832 │ concatenate_9[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 64, 64,    │    401,440 │ concatenate_9[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ conv2d_38[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_39[0][0],  │
# │                     │                   │            │ conv2d_40[0][0],  │
# │                     │                   │            │ conv2d_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 64, 64,    │    147,584 │ concatenate_10[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ conv2d_42[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 128, 128,  │     32,832 │ up_sampling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ conv2d_43[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 128, 128,  │      2,064 │ concatenate_11[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 128, 128,  │     18,448 │ concatenate_11[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 128, 128,  │     51,216 │ concatenate_11[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 128, 128,  │    100,368 │ concatenate_11[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 128, 128,  │          0 │ conv2d_44[0][0],  │
# │ (Concatenate)       │ 64)               │            │ conv2d_45[0][0],  │
# │                     │                   │            │ conv2d_46[0][0],  │
# │                     │                   │            │ conv2d_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 128, 128,  │     36,928 │ concatenate_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_48[0][0]   │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 128, 128,  │          0 │ conv2d_49[0][0],  │
# │ (Concatenate)       │ 2)                │            │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │         48 │ concatenate_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │        304 │ concatenate_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 128, 128,  │        816 │ concatenate_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 128, 128,  │      1,584 │ concatenate_13[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 128, 128,  │          0 │ conv2d_50[0][0],  │
# │ (Concatenate)       │ 64)               │            │ conv2d_51[0][0],  │
# │                     │                   │            │ conv2d_52[0][0],  │
# │                     │                   │            │ conv2d_53[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 128, 128,  │     36,928 │ concatenate_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv2d_54[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 64, 64,    │      2,080 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 64, 64,    │     18,464 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 64, 64,    │     51,232 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 64, 64,    │    100,384 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 64, 64,    │          0 │ conv2d_55[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_56[0][0],  │
# │                     │                   │            │ conv2d_57[0][0],  │
# │                     │                   │            │ conv2d_58[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 64, 64,    │    147,584 │ concatenate_15[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ conv2d_59[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 32, 32,    │      8,256 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 32, 32,    │     73,792 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 32, 32,    │    204,864 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 32, 32,    │    401,472 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 32, 32,    │          0 │ conv2d_60[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_61[0][0],  │
# │                     │                   │            │ conv2d_62[0][0],  │
# │                     │                   │            │ conv2d_63[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 32, 32,    │    590,080 │ concatenate_16[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ conv2d_64[0][0]   │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 16, 16,    │     32,896 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 16, 16,    │    295,040 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (None, 16, 16,    │    819,328 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (None, 16, 16,    │  1,605,760 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 16, 16,    │          0 │ conv2d_65[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_66[0][0],  │
# │                     │                   │            │ conv2d_67[0][0],  │
# │                     │                   │            │ conv2d_68[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ concatenate_17[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 512) │          0 │ conv2d_69[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 8, 8, 256) │    131,328 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 8, 8, 256) │  1,179,904 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 8, 8, 256) │  3,277,056 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 8, 8, 256) │  6,422,784 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 8, 8,      │          0 │ conv2d_70[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ conv2d_71[0][0],  │
# │                     │                   │            │ conv2d_72[0][0],  │
# │                     │                   │            │ conv2d_73[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 8, 8,      │  9,438,208 │ concatenate_18[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 16, 16,    │          0 │ conv2d_74[0][0]   │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 16, 16,    │  2,097,664 │ up_sampling2d_4[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 16, 16,    │          0 │ conv2d_75[0][0],  │
# │ (Concatenate)       │ 1024)             │            │ conv2d_69[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 16, 16,    │    131,200 │ concatenate_19[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 16, 16,    │  1,179,776 │ concatenate_19[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 16, 16,    │  3,276,928 │ concatenate_19[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 16, 16,    │  6,422,656 │ concatenate_19[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 16, 16,    │          0 │ conv2d_76[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_77[0][0],  │
# │                     │                   │            │ conv2d_78[0][0],  │
# │                     │                   │            │ conv2d_79[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ concatenate_20[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 32, 32,    │          0 │ conv2d_80[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 32, 32,    │    524,544 │ up_sampling2d_5[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 32, 32,    │          0 │ conv2d_81[0][0],  │
# │ (Concatenate)       │ 512)              │            │ conv2d_64[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 32, 32,    │     32,832 │ concatenate_21[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 32, 32,    │    294,976 │ concatenate_21[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 32, 32,    │    819,264 │ concatenate_21[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 32, 32,    │  1,605,696 │ concatenate_21[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 32, 32,    │          0 │ conv2d_82[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_83[0][0],  │
# │                     │                   │            │ conv2d_84[0][0],  │
# │                     │                   │            │ conv2d_85[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 32, 32,    │    590,080 │ concatenate_22[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 64, 64,    │          0 │ conv2d_86[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 64, 64,    │    131,200 │ up_sampling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 64, 64,    │          0 │ conv2d_87[0][0],  │
# │ (Concatenate)       │ 256)              │            │ conv2d_59[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 64, 64,    │      8,224 │ concatenate_23[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 64, 64,    │     73,760 │ concatenate_23[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 64, 64,    │    204,832 │ concatenate_23[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 64, 64,    │    401,440 │ concatenate_23[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 64, 64,    │          0 │ conv2d_88[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_89[0][0],  │
# │                     │                   │            │ conv2d_90[0][0],  │
# │                     │                   │            │ conv2d_91[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 64, 64,    │    147,584 │ concatenate_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 128, 128,  │          0 │ conv2d_92[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 128, 128,  │     32,832 │ up_sampling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 128, 128,  │          0 │ conv2d_93[0][0],  │
# │ (Concatenate)       │ 128)              │            │ conv2d_54[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 128, 128,  │      2,064 │ concatenate_25[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 128, 128,  │     18,448 │ concatenate_25[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 128, 128,  │     51,216 │ concatenate_25[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 128, 128,  │    100,368 │ concatenate_25[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 128, 128,  │          0 │ conv2d_94[0][0],  │
# │ (Concatenate)       │ 64)               │            │ conv2d_95[0][0],  │
# │                     │                   │            │ conv2d_96[0][0],  │
# │                     │                   │            │ conv2d_97[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 128, 128,  │     36,928 │ concatenate_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_98[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 95,487,426 (364.26 MB)
#  Trainable params: 95,487,426 (364.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Modelin Train Edilmesi

# %%
total_epoch = 100
batch_size = 100
alpha = 10
beta = 1
path = './'
model_path = path + 'exp/model.keras'
Adam = keras.optimizers.Adam(learning_rate=1e-4)
lr_metric = get_lr_metric(Adam)
model.compile(optimizer=Adam, loss=['mse', 'mse'], loss_weights=[alpha, beta], metrics=['mae', 'mae'])
model_checkpoint = keras.callbacks.ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True)
lr_checkpoint = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.95, patience=2, min_lr=0)
history = model.fit(x=train_data, y=[train_mask1, train_mask2], batch_size=batch_size, epochs=total_epoch, verbose=2, \
    validation_data=(test_data, [test_mask1, test_mask2]), callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.72734, saving model to ./exp/model.keras
# 2/2 - 212s - 106s/step - conv2d_49_mae: 0.5192 - conv2d_99_mae: 0.0279 - loss: 2.7215 - val_conv2d_49_mae: 0.5192 - val_conv2d_99_mae: 0.0175 - val_loss: 2.7273
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.72734 to 2.13645, saving model to ./exp/model.keras
# 2/2 - 206s - 103s/step - conv2d_49_mae: 0.5087 - conv2d_99_mae: 0.0141 - loss: 2.5791 - val_conv2d_49_mae: 0.4588 - val_conv2d_99_mae: 0.0093 - val_loss: 2.1365
# Epoch 3/100
#
# Epoch 3: val_loss improved from 2.13645 to 1.38688, saving model to ./exp/model.keras
# 2/2 - 243s - 121s/step - conv2d_49_mae: 0.4465 - conv2d_99_mae: 0.0099 - loss: 1.9851 - val_conv2d_49_mae: 0.3674 - val_conv2d_99_mae: 0.0166 - val_loss: 1.3869
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 1.38688
# 2/2 - 183s - 91s/step - conv2d_49_mae: 0.3084 - conv2d_99_mae: 0.0139 - loss: 0.9410 - val_conv2d_49_mae: 0.5056 - val_conv2d_99_mae: 0.0107 - val_loss: 3.4377
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.38688 to 0.53473, saving model to ./exp/model.keras
# 2/2 - 202s - 101s/step - conv2d_49_mae: 0.3669 - conv2d_99_mae: 0.0139 - loss: 1.8160 - val_conv2d_49_mae: 0.2170 - val_conv2d_99_mae: 0.0095 - val_loss: 0.5347
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.53473
# 2/2 - 212s - 106s/step - conv2d_49_mae: 0.2328 - conv2d_99_mae: 0.0097 - loss: 0.6342 - val_conv2d_49_mae: 0.2796 - val_conv2d_99_mae: 0.0096 - val_loss: 0.8214
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.53473
# 2/2 - 237s - 118s/step - conv2d_49_mae: 0.2776 - conv2d_99_mae: 0.0119 - loss: 0.8060 - val_conv2d_49_mae: 0.2648 - val_conv2d_99_mae: 0.0103 - val_loss: 0.7400
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.53473 to 0.53063, saving model to ./exp/model.keras
# 2/2 - 222s - 111s/step - conv2d_49_mae: 0.2570 - conv2d_99_mae: 0.0092 - loss: 0.6875 - val_conv2d_49_mae: 0.2210 - val_conv2d_99_mae: 0.0046 - val_loss: 0.5306
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.53063 to 0.28414, saving model to ./exp/model.keras
# 2/2 - 251s - 126s/step - conv2d_49_mae: 0.2091 - conv2d_99_mae: 0.0062 - loss: 0.4674 - val_conv2d_49_mae: 0.1530 - val_conv2d_99_mae: 0.0103 - val_loss: 0.2841
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.28414 to 0.10486, saving model to ./exp/model.keras
# 2/2 - 205s - 103s/step - conv2d_49_mae: 0.1353 - conv2d_99_mae: 0.0095 - loss: 0.2234 - val_conv2d_49_mae: 0.0653 - val_conv2d_99_mae: 0.0087 - val_loss: 0.1049
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.10486
# 2/2 - 216s - 108s/step - conv2d_49_mae: 0.0758 - conv2d_99_mae: 0.0086 - loss: 0.1274 - val_conv2d_49_mae: 0.1217 - val_conv2d_99_mae: 0.0190 - val_loss: 0.2034
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.10486
# 2/2 - 214s - 107s/step - conv2d_49_mae: 0.1183 - conv2d_99_mae: 0.0148 - loss: 0.1883 - val_conv2d_49_mae: 0.0884 - val_conv2d_99_mae: 0.0095 - val_loss: 0.1254
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.10486 to 0.07369, saving model to ./exp/model.keras
# 2/2 - 198s - 99s/step - conv2d_49_mae: 0.0808 - conv2d_99_mae: 0.0085 - loss: 0.1065 - val_conv2d_49_mae: 0.0549 - val_conv2d_99_mae: 0.0126 - val_loss: 0.0737
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.07369 to 0.06835, saving model to ./exp/model.keras
# 2/2 - 179s - 90s/step - conv2d_49_mae: 0.0515 - conv2d_99_mae: 0.0130 - loss: 0.0698 - val_conv2d_49_mae: 0.0514 - val_conv2d_99_mae: 0.0050 - val_loss: 0.0683
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.06835 to 0.06494, saving model to ./exp/model.keras
# 2/2 - 233s - 117s/step - conv2d_49_mae: 0.0487 - conv2d_99_mae: 0.0064 - loss: 0.0658 - val_conv2d_49_mae: 0.0502 - val_conv2d_99_mae: 0.0053 - val_loss: 0.0649
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.06494 to 0.06022, saving model to ./exp/model.keras
# 2/2 - 199s - 99s/step - conv2d_49_mae: 0.0470 - conv2d_99_mae: 0.0069 - loss: 0.0618 - val_conv2d_49_mae: 0.0488 - val_conv2d_99_mae: 0.0116 - val_loss: 0.0602
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.06022 to 0.05691, saving model to ./exp/model.keras
# 2/2 - 199s - 99s/step - conv2d_49_mae: 0.0466 - conv2d_99_mae: 0.0111 - loss: 0.0582 - val_conv2d_49_mae: 0.0485 - val_conv2d_99_mae: 0.0048 - val_loss: 0.0569
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.05691 to 0.05207, saving model to ./exp/model.keras
# 2/2 - 186s - 93s/step - conv2d_49_mae: 0.0456 - conv2d_99_mae: 0.0055 - loss: 0.0542 - val_conv2d_49_mae: 0.0457 - val_conv2d_99_mae: 0.0054 - val_loss: 0.0521
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.05207 to 0.04870, saving model to ./exp/model.keras
# 2/2 - 196s - 98s/step - conv2d_49_mae: 0.0429 - conv2d_99_mae: 0.0071 - loss: 0.0497 - val_conv2d_49_mae: 0.0449 - val_conv2d_99_mae: 0.0090 - val_loss: 0.0487
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.04870 to 0.04518, saving model to ./exp/model.keras
# 2/2 - 207s - 104s/step - conv2d_49_mae: 0.0420 - conv2d_99_mae: 0.0088 - loss: 0.0466 - val_conv2d_49_mae: 0.0444 - val_conv2d_99_mae: 0.0056 - val_loss: 0.0452
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.04518 to 0.04132, saving model to ./exp/model.keras
# 2/2 - 212s - 106s/step - conv2d_49_mae: 0.0418 - conv2d_99_mae: 0.0062 - loss: 0.0428 - val_conv2d_49_mae: 0.0430 - val_conv2d_99_mae: 0.0076 - val_loss: 0.0413
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.04132 to 0.03744, saving model to ./exp/model.keras
# 2/2 - 227s - 113s/step - conv2d_49_mae: 0.0402 - conv2d_99_mae: 0.0086 - loss: 0.0391 - val_conv2d_49_mae: 0.0417 - val_conv2d_99_mae: 0.0065 - val_loss: 0.0374
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.03744 to 0.03360, saving model to ./exp/model.keras
# 2/2 - 236s - 118s/step - conv2d_49_mae: 0.0390 - conv2d_99_mae: 0.0071 - loss: 0.0350 - val_conv2d_49_mae: 0.0399 - val_conv2d_99_mae: 0.0068 - val_loss: 0.0336
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.03360 to 0.03165, saving model to ./exp/model.keras
# 2/2 - 237s - 118s/step - conv2d_49_mae: 0.0371 - conv2d_99_mae: 0.0076 - loss: 0.0314 - val_conv2d_49_mae: 0.0397 - val_conv2d_99_mae: 0.0085 - val_loss: 0.0316
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.03165
# 2/2 - 220s - 110s/step - conv2d_49_mae: 0.0386 - conv2d_99_mae: 0.0087 - loss: 0.0324 - val_conv2d_49_mae: 0.0444 - val_conv2d_99_mae: 0.0062 - val_loss: 0.0353
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.03165 to 0.03098, saving model to ./exp/model.keras
# 2/2 - 193s - 96s/step - conv2d_49_mae: 0.0401 - conv2d_99_mae: 0.0069 - loss: 0.0307 - val_conv2d_49_mae: 0.0402 - val_conv2d_99_mae: 0.0075 - val_loss: 0.0310
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.03098 to 0.02950, saving model to ./exp/model.keras
# 2/2 - 209s - 105s/step - conv2d_49_mae: 0.0369 - conv2d_99_mae: 0.0082 - loss: 0.0282 - val_conv2d_49_mae: 0.0396 - val_conv2d_99_mae: 0.0059 - val_loss: 0.0295
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.02950 to 0.02663, saving model to ./exp/model.keras
# 2/2 - 234s - 117s/step - conv2d_49_mae: 0.0361 - conv2d_99_mae: 0.0065 - loss: 0.0266 - val_conv2d_49_mae: 0.0367 - val_conv2d_99_mae: 0.0075 - val_loss: 0.0266
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.02663 to 0.02485, saving model to ./exp/model.keras
# 2/2 - 245s - 123s/step - conv2d_49_mae: 0.0340 - conv2d_99_mae: 0.0086 - loss: 0.0251 - val_conv2d_49_mae: 0.0352 - val_conv2d_99_mae: 0.0070 - val_loss: 0.0248
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.02485 to 0.02458, saving model to ./exp/model.keras
# 2/2 - 320s - 160s/step - conv2d_49_mae: 0.0328 - conv2d_99_mae: 0.0076 - loss: 0.0237 - val_conv2d_49_mae: 0.0352 - val_conv2d_99_mae: 0.0072 - val_loss: 0.0246
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.02458 to 0.02418, saving model to ./exp/model.keras
# 2/2 - 340s - 170s/step - conv2d_49_mae: 0.0322 - conv2d_99_mae: 0.0081 - loss: 0.0235 - val_conv2d_49_mae: 0.0349 - val_conv2d_99_mae: 0.0058 - val_loss: 0.0242
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.02418
# 2/2 - 294s - 147s/step - conv2d_49_mae: 0.0317 - conv2d_99_mae: 0.0064 - loss: 0.0228 - val_conv2d_49_mae: 0.0357 - val_conv2d_99_mae: 0.0075 - val_loss: 0.0247
# Epoch 33/100

# %% [markdown]
# # Modelin Test Verileri Üzerindeki Performansının Değerlendirilmesi

# %%
model.load_weights(model_path)
model.evaluate(x=test_data, y=[test_mask1, test_mask2], batch_size=batch_size)
[test_pred1, test_pred2] = model.predict(test_data)
for i in range(len(test_data)):
    pred1 = test_pred1[i].reshape(image_sizeX, image_sizeY) * 255
    pred1 = Image.fromarray(pred1)
    pred1.convert('L').save(path + 'exp/visual/1pred_%d.png'%(i+1))
    pred2 = test_pred2[i].reshape(image_sizeX, image_sizeY) * 255
    pred2 = Image.fromarray(pred2)
    pred2.convert('L').save(path + 'exp/visual/2pred_%d.png'%(i+1))

# %% [markdown]
# # Modelin Verilen Index Ile Bir Örneğe Uygulanması

# %%
index = 0  # Örnek bir indeks seçilebilir
input_image = test_data[index]
predicted_mask1, predicted_mask2 = model.predict(np.expand_dims(input_image, axis=0))

plt.figure(figsize=(10, 5))

# Giriş görüntüsü
plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(input_image), cmap='gray')
plt.title('Input Image')
plt.axis('off')

# Tahmin edilen maskelerden biri
plt.subplot(1, 2, 2)
plt.imshow(np.squeeze(predicted_mask1), cmap='gray')
plt.title('Predicted Mask 1')
plt.axis('off')

plt.show()
